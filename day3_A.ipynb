# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# **Line Plot**

# %%
x= np.array([3,13,45,65,78,98])
y= np.array([3,14,18,35,56,95])
z= np.array([83,63,45,31,28,9])

# %%
plt.title('My first plot')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.xlim(0,100)
plt.ylim(0,100)
plt.xticks(range(0,101,10))
plt.yticks(range(0,101,10))
plt.plot(x,y)

# %%
plt.title('My first plot')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.xlim(0,100)
plt.ylim(0,100)
plt.xticks(range(0,101,10))
plt.yticks(range(0,101,10))
plt.plot(x,z)

# %%
plt.title('My first plot')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
#markers: . o x v > ^ < D *
plt.plot(x,y, color='blue',marker='o', ls=':',mfc='green')

# %%
plt.title('My first plot')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
#markers: . o x v > ^ < D *
plt.plot(x,y, color='blue', label='2023') 
plt.plot(x,z, color='red', label='2022') 
plt.legend()

# %%
plt.subplot(2,1,1)
plt.plot(x,y)
plt.subplot(2,1,2)
plt.plot(x,z)

# %%
plt.subplot(121)
plt.plot(x,y)
plt.subplot(122)
plt.plot(x,z)

# %%
plt.figure(figsize=(16,9))
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.plot(x,z ,lw=5, marker ='o', ms=20, mfc='r')  
plt.savefig('myplot.png')

# %% [markdown]
# **Scatter Plot**

# %%
plt.title('My first plot')
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.scatter(x,y)

# %%
java=np.array([45,55,24,36,49,86,88,25,36,75])
python=np.array([78,45,35,65,49,15,26,98,34,69])
cols=[1,2,3,3,2,1,2,1,3,2]

# %%
plt.title('Result')
plt.xlabel('java Marks')
plt.ylabel('Python Marks')
plt.grid()
plt.scatter(java,python, c=cols)

# %% [markdown]
# **Bar Plot**

# %%
enrollment=[104,112,256,178,126,180]
courses=['C','Java','Python','R','PHP','Javascript']

# %%
plt.xlabel('Courses')
plt.ylabel('Enrolled Students')
plt.grid()
plt.bar(courses, enrollment,color='brown')
# Out:
# <BarContainer object of 6 artists>

# %%
plt.ylabel('Courses')
plt.xlabel('Enrolled Students')
plt.grid()
plt.barh(courses, enrollment,color='blue')
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# **Pie Chart**

# %%
plt.figure(figsize=(10,10))
plt.pie(enrollment, labels=courses , autopct='%2.2f', shadow=True);

# %% [markdown]
# **UniVariate Analysis**

# %% [markdown]
# **Histogram**

# %%
marks=np.array([45,87,25,36,16,98,28])

# %%
plt.title('Frequency plot of Marks')
plt.xlabel('Range of Marks')
plt.ylabel('Count')
plt.grid()
plt.xticks(range(0,101,10))
plt.hist(marks, bins=range(0,101,10), color='gold');

# %% [markdown]
# **Box Plot**

# %%
plt.boxplot(marks);

# %% [markdown]
# **Machine Learning**

# %% [markdown]
# **Regression**

# %%
#DataSet : Salary_Data.csv, mtcars.csv, Social_Network_Ads.csv
#Mall_Customers.csv
#Location : https://mitu.co.in/dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Salary_Data.csv')

# %%
df.shape
# Out:
# (30, 2)

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
plt.scatter(df['YearsExperience'], df['Salary'])

# %% [markdown]
# **Separate the input and output data**

# %%
x=df['YearsExperience'].values
y=df['Salary']

# %%
x
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
y;

# %%
x=x.reshape(30,1)

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %% [markdown]
# **Import the linear regression class**

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# **Create the object of linear regression**

# %%
regressor = LinearRegression()

# %% [markdown]
# **train the algorithm**

# %%
regressor.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# **Predict the unseen data**

# %%
regressor.predict([[15]])
# Out:
# array([167541.63502049])

# %%
regressor.predict([[20]])
# Out:
# array([214791.44662777])

# %%
regressor.score(x,y)
# Out:
# 0.9569566641435086
